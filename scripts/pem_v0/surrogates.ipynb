# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, MaxAbsScaler, RobustScaler, Normalizer
from sklearn.model_selection import GridSearchCV
import os
import ast

from pathlib import Path
import pickle

from amisc.system import SystemSurrogate
from uqtils import ax_default

# %%
# Load the full SystemSurrogate
save_dir = 'mf_2024-06-12T23.50.31/multi-fidelity/amisc_2024-06-12T23.50.31'
base_dir = Path('../../results')
root_dir = base_dir / save_dir
surr = SystemSurrogate.load_from_file(root_dir / 'sys' / 'sys_final.pkl', root_dir=root_dir)
surr._set_output_dir({'Thruster': None})  # Don't save outputs for testing
sys_qoi = [1, 2, 8, 9]
thruster_qoi = [i-1 for i in sys_qoi]

# %%
# Load training set
thruster = surr['Thruster']
xdim, ydim = len(thruster.x_vars), thruster.ydim
xi, yi = thruster.get_training_data()
xtrain, ytrain = np.empty((0, xdim)), np.empty((0, ydim))

# Combine data from multiple model fidelities
for alpha, x in xi.items():
    for i in range(x.shape[0]):
        # Keep highest-fidelity training samples for duplicate x
        diff = np.abs(xtrain - x[i, :])
        idx = np.count_nonzero(diff, axis=-1) == 0  
        if np.any(idx):
            # print(f'{alpha}: i={i}, x={x[i, :]}')
            ytrain[idx, :] = yi[alpha][i, :]  # Should at most only have one True
        else:
            xtrain = np.concatenate((xtrain, x[np.newaxis, i, :]), axis=0)
            ytrain = np.concatenate((ytrain, yi[alpha][np.newaxis, i, :]), axis=0)
ytrain = ytrain[:, thruster_qoi]
xtrain.shape, ytrain.shape
# Out:
# ((541, 16), (541, 4))

# %%
# Make sure there are no duplicate x's remaining in the training set
diff = np.abs(np.expand_dims(xtrain, axis=0) - np.expand_dims(xtrain, axis=1))
idx = np.count_nonzero(diff, axis=-1) == 0
idx = np.count_nonzero(idx, axis=-1)  # Should be identity matrix of length Nx (each point is only equal to itself)
np.any(idx > 1)
# Out:
# False

# %%
# Load system test set
# with open(Path('../../models/data') / 'test_set.pkl', 'rb') as fd:
#     data = pickle.load(fd)
#     xtest_sys, ytest_sys = data['xt'], data['yt']
xtest_sys, ytest_sys = surr.build_metrics['xt'], surr.build_metrics['yt']
xtest_sys.shape, ytest_sys.shape
# Out:
# ((499, 26), (499, 18))

# %%
# Get system surrogate prediction
yt_surr = surr(xtest_sys)
yt_surr = yt_surr[:, sys_qoi]   # (Nt, Nq)
yt_surr.shape
# Out:
# (499, 4)

# %%
# Convert test set to thruster inputs/outputs
exo_in = surr.graph.nodes['Thruster']['exo_in']
global_in = surr.graph.nodes['Thruster']['global_in']
xtest = np.concatenate((xtest_sys[:, exo_in], ytest_sys[:, global_in]), axis=-1)    # (Nt, 12)
ytest = ytest_sys[:, sys_qoi]                                                       # (Nt, Nq)
xtest.shape, ytest.shape
# Out:
# ((499, 16), (499, 4))

# %%
# Test MISC surrogate on training set
model = surr.get_component('Thruster')
ytrain_ridge = model(xtrain)[:, thruster_qoi]
r2 = 1 - np.sum((ytrain_ridge - ytrain)**2, axis=0) / np.sum((ytrain_ridge - np.mean(ytrain_ridge, axis=0))**2, axis=0)
rel_error = np.sqrt(np.mean((ytest - yt_surr)**2, axis=0)) / np.sqrt(np.mean(ytest**2, axis=0))     # (Nq,)
print(f'Training set R2 values: {r2}. Uniform average: {np.mean(r2)}')
print(f'Relative L2 error on test set: {rel_error}')
rel_error = np.sqrt(np.mean((ytrain - ytrain_ridge)**2, axis=0)) / np.sqrt(np.mean(ytrain**2, axis=0))     # (Nq,)
print(f'Relative L2 error on training set: {rel_error}')

fig, axs = plt.subplots(1, len(sys_qoi))
labels = [surr.coupling_vars[i].to_tex(units=True) for i in sys_qoi]
for i in range(len(sys_qoi)):
    ax = axs[i] if len(sys_qoi) > 1 else axs
    ax.scatter(ytrain[:, i], ytrain_ridge[:, i], c='r', s=1.5)
    ax.plot(ytrain[:, i], ytrain[:, i], '-k')
    ax.set_title(labels[i])
    ax_default(ax, 'Actual', 'Predicted', legend=False)
fig.set_size_inches(3*len(sys_qoi), 3)
fig.tight_layout()
plt.show()
# Out:
# Training set R2 values: [0.44520329 0.94367584 0.98901667 0.99538424]. Uniform average: 0.8433200099382856
# Relative L2 error on test set: [0.11860346 0.19306151 0.00193402 0.10018476]
# Relative L2 error on training set: [0.2911025  0.15812674 0.10191463 0.06329877]

# %%
# Test scikit-learn regression
model = Ridge(alpha=0.1)
model.fit(xtrain, ytrain)
yt_ridge = model.predict(xtest)
ytrain_ridge = model.predict(xtrain)
r2 = 1 - np.sum((ytrain_ridge - ytrain)**2, axis=0) / np.sum((ytrain_ridge - np.mean(ytrain_ridge, axis=0))**2, axis=0)
rel_error = np.sqrt(np.mean((ytest - yt_ridge)**2, axis=0)) / np.sqrt(np.mean(ytest**2, axis=0))     # (Nq,)
print(f'Training set R2 values: {r2}. Uniform average: {np.mean(r2)}')
print(f'Relative L2 error on test set: {rel_error}')
rel_error = np.sqrt(np.mean((ytrain - ytrain_ridge)**2, axis=0)) / np.sqrt(np.mean(ytrain**2, axis=0))     # (Nq,)
print(f'Relative L2 error on training set: {rel_error}')

fig, axs = plt.subplots(1, len(sys_qoi))
for i in range(len(sys_qoi)):
    ax = axs[i] if len(sys_qoi) > 1 else axs
    ax.scatter(ytrain[:, i], ytrain_ridge[:, i], c='r', s=1.5)
    ax.plot(ytrain[:, i], ytrain[:, i], '-k')
    ax.set_title(labels[i])
    ax_default(ax, 'Actual', 'Predicted', legend=False)
fig.set_size_inches(3*len(sys_qoi), 3)
fig.tight_layout()
plt.show()
# Out:
# Training set R2 values: [ 0.84239585  0.36326418  0.36323565 -0.98026064]. Uniform average: 0.14715876067633737
# Relative L2 error on test set: [ 0.27883715  0.42996192 11.6086408  88.77031039]
# Relative L2 error on training set: [0.11350263 0.36297588 0.60752661 0.76696649]

# %%
# Test scikit-learn regression
pipe = Pipeline([('scaler', StandardScaler()),
                  ('features', PolynomialFeatures()),
                  ('model', Ridge(alpha=1))])
params = {'features__degree': [2, 3, 4],
          'scaler': [StandardScaler(), MaxAbsScaler()]
          }
model = GridSearchCV(pipe, params, cv=5, verbose=3)
model.fit(xtrain, ytrain)
yt_ridge = model.predict(xtest)
ytrain_ridge = model.predict(xtrain)
r2 = 1 - np.sum((ytrain_ridge - ytrain)**2, axis=0) / np.sum((ytrain_ridge - np.mean(ytrain_ridge, axis=0))**2, axis=0)
rel_error = np.sqrt(np.mean((ytest - yt_ridge)**2, axis=0)) / np.sqrt(np.mean(ytest**2, axis=0))     # (Nq,)
print(f'Training set R2 values: {r2}. Uniform average: {np.mean(r2)}')
print(f'Relative L2 error on test set: {rel_error}')
rel_error = np.sqrt(np.mean((ytrain - ytrain_ridge)**2, axis=0)) / np.sqrt(np.mean(ytrain**2, axis=0))     # (Nq,)
print(f'Relative L2 error on training set: {rel_error}')

fig, axs = plt.subplots(1, len(sys_qoi))
for i in range(len(sys_qoi)):
    ax = axs[i] if len(sys_qoi) > 1 else axs
    ax.scatter(ytrain[:, i], ytrain_ridge[:, i], c='r', s=1.5)
    ax.plot(ytrain[:, i], ytrain[:, i], '-k')
    ax.set_title(labels[i])
    ax_default(ax, 'Actual', 'Predicted', legend=False)
fig.set_size_inches(3*len(sys_qoi), 3)
fig.tight_layout()
plt.show()
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END features__degree=2, scaler=StandardScaler();, score=0.827 total time=   0.1s
# [CV 2/5] END features__degree=2, scaler=StandardScaler();, score=0.855 total time=   0.1s
# [CV 3/5] END features__degree=2, scaler=StandardScaler();, score=0.681 total time=   0.1s
# [CV 4/5] END features__degree=2, scaler=StandardScaler();, score=0.842 total time=   0.1s
# [CV 5/5] END features__degree=2, scaler=StandardScaler();, score=0.846 total time=   0.1s
# [CV 1/5] END features__degree=2, scaler=MaxAbsScaler();, score=0.723 total time=   0.1s
# [CV 2/5] END features__degree=2, scaler=MaxAbsScaler();, score=0.782 total time=   0.1s
# [CV 3/5] END features__degree=2, scaler=MaxAbsScaler();, score=0.622 total time=   0.0s
# [CV 4/5] END features__degree=2, scaler=MaxAbsScaler();, score=0.762 total time=   0.0s
# [CV 5/5] END features__degree=2, scaler=MaxAbsScaler();, score=0.770 total time=   0.2s
# [CV 1/5] END features__degree=3, scaler=StandardScaler();, score=0.843 total time=   0.5s
# [CV 2/5] END features__degree=3, scaler=StandardScaler();, score=0.793 total time=   0.2s
# [CV 3/5] END features__degree=3, scaler=StandardScaler();, score=0.722 total time=   0.2s
# [CV 4/5] END features__degree=3, scaler=StandardScaler();, score=0.876 total time=   0.2s
# [CV 5/5] END features__degree=3, scaler=StandardScaler();, score=0.868 total time=   0.1s
# [CV 1/5] END features__degree=3, scaler=MaxAbsScaler();, score=0.789 total time=   0.1s
# [CV 2/5] END features__degree=3, scaler=MaxAbsScaler();, score=0.832 total time=   0.1s
# [CV 3/5] END features__degree=3, scaler=MaxAbsScaler();, score=0.712 total time=   0.2s
# [CV 4/5] END features__degree=3, scaler=MaxAbsScaler();, score=0.836 total time=   0.2s
# [CV 5/5] END features__degree=3, scaler=MaxAbsScaler();, score=0.852 total time=   0.2s
# [CV 1/5] END features__degree=4, scaler=StandardScaler();, score=0.835 total time=   0.5s
# [CV 2/5] END features__degree=4, scaler=StandardScaler();, score=0.561 total time=   0.5s
# [CV 3/5] END features__degree=4, scaler=StandardScaler();, score=0.653 total time=   0.8s
# [CV 4/5] END features__degree=4, scaler=StandardScaler();, score=0.625 total time=   0.9s
# [CV 5/5] END features__degree=4, scaler=StandardScaler();, score=0.824 total time=   0.5s
# [CV 1/5] END features__degree=4, scaler=MaxAbsScaler();, score=0.716 total time=   0.4s
# [CV 2/5] END features__degree=4, scaler=MaxAbsScaler();, score=0.841 total time=   0.5s
# [CV 3/5] END features__degree=4, scaler=MaxAbsScaler();, score=0.712 total time=   0.4s
# [CV 4/5] END features__degree=4, scaler=MaxAbsScaler();, score=0.849 total time=   0.2s
# [CV 5/5] END features__degree=4, scaler=MaxAbsScaler();, score=0.851 total time=   0.4s
# Training set R2 values: [0.92248265 0.94242176 0.96100743 0.9281721 ]. Uniform average: 0.9385209852695368
# Relative L2 error on test set: [  0.53039004   0.48446415  11.88225401 122.1640852 ]
# Relative L2 error on training set: [0.08240337 0.13652375 0.18858776 0.24405563]

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern, RBF

pipe = Pipeline([('scaler', MaxAbsScaler()),
                  ('model', GaussianProcessRegressor(n_restarts_optimizer=0, kernel=RBF(length_scale_bounds='fixed')))])
params = {'model__alpha': [1e-2, 1e-1],
          'model__kernel__length_scale': [0.01, 0.1, 1, 10]
          }
model = GridSearchCV(pipe, params, cv=5, verbose=3)
model.fit(xtrain, ytrain)
r2 = model.score(xtrain, ytrain)
yt_ridge = model.predict(xtest)
ytrain_ridge = model.predict(xtrain)
r2 = 1 - np.sum((ytrain_ridge - ytrain)**2, axis=0) / np.sum((ytrain_ridge - np.mean(ytrain_ridge, axis=0))**2, axis=0)
rel_error = np.sqrt(np.mean((ytest - yt_ridge)**2, axis=0)) / np.sqrt(np.mean(ytest**2, axis=0))     # (Nq,)
print(f'Training set R2 values: {r2}. Uniform average: {np.mean(r2)}')
print(f'Relative L2 error on test set: {rel_error}')
rel_error = np.sqrt(np.mean((ytrain - ytrain_ridge)**2, axis=0)) / np.sqrt(np.mean(ytrain**2, axis=0))     # (Nq,)
print(f'Relative L2 error on training set: {rel_error}')

fig, axs = plt.subplots(1, len(sys_qoi))
for i in range(len(sys_qoi)):
    ax = axs[i] if len(sys_qoi) > 1 else axs
    ax.scatter(ytrain[:, i], ytrain_ridge[:, i], c='r', s=1.5)
    ax.plot(ytrain[:, i], ytrain[:, i], '-k')
    ax.set_title(labels[i])
    ax_default(ax, 'Actual', 'Predicted', legend=False)
fig.set_size_inches(3*len(sys_qoi), 3)
fig.tight_layout()
plt.show()
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END model__alpha=0.01, model__kernel__length_scale=0.01;, score=-2.976 total time=   0.2s
# [CV 2/5] END model__alpha=0.01, model__kernel__length_scale=0.01;, score=-4.252 total time=   0.3s
# [CV 3/5] END model__alpha=0.01, model__kernel__length_scale=0.01;, score=-1.550 total time=   0.3s
# [CV 4/5] END model__alpha=0.01, model__kernel__length_scale=0.01;, score=-5.893 total time=   0.3s
# [CV 5/5] END model__alpha=0.01, model__kernel__length_scale=0.01;, score=-3.264 total time=   0.5s
# [CV 1/5] END model__alpha=0.01, model__kernel__length_scale=0.1;, score=-1.051 total time=   0.4s
# [CV 2/5] END model__alpha=0.01, model__kernel__length_scale=0.1;, score=-2.460 total time=   0.3s
# [CV 3/5] END model__alpha=0.01, model__kernel__length_scale=0.1;, score=-0.989 total time=   0.1s
# [CV 4/5] END model__alpha=0.01, model__kernel__length_scale=0.1;, score=-4.493 total time=   0.1s
# [CV 5/5] END model__alpha=0.01, model__kernel__length_scale=0.1;, score=-1.972 total time=   0.1s
# [CV 1/5] END model__alpha=0.01, model__kernel__length_scale=1;, score=0.851 total time=   0.2s
# [CV 2/5] END model__alpha=0.01, model__kernel__length_scale=1;, score=0.872 total time=   0.4s
# [CV 3/5] END model__alpha=0.01, model__kernel__length_scale=1;, score=0.777 total time=   0.2s
# [CV 4/5] END model__alpha=0.01, model__kernel__length_scale=1;, score=0.887 total time=   0.2s
# [CV 5/5] END model__alpha=0.01, model__kernel__length_scale=1;, score=0.883 total time=   0.3s
# [CV 1/5] END model__alpha=0.01, model__kernel__length_scale=10;, score=0.599 total time=   0.3s
# [CV 2/5] END model__alpha=0.01, model__kernel__length_scale=10;, score=0.683 total time=   0.1s
# [CV 3/5] END model__alpha=0.01, model__kernel__length_scale=10;, score=0.472 total time=   0.1s
# [CV 4/5] END model__alpha=0.01, model__kernel__length_scale=10;, score=0.627 total time=   0.5s
# [CV 5/5] END model__alpha=0.01, model__kernel__length_scale=10;, score=0.650 total time=   0.1s
# [CV 1/5] END model__alpha=0.1, model__kernel__length_scale=0.01;, score=-2.977 total time=   0.1s
# [CV 2/5] END model__alpha=0.1, model__kernel__length_scale=0.01;, score=-4.252 total time=   0.1s
# [CV 3/5] END model__alpha=0.1, model__kernel__length_scale=0.01;, score=-1.550 total time=   0.1s
# [CV 4/5] END model__alpha=0.1, model__kernel__length_scale=0.01;, score=-5.893 total time=   0.2s
# [CV 5/5] END model__alpha=0.1, model__kernel__length_scale=0.01;, score=-3.267 total time=   0.2s
# [CV 1/5] END model__alpha=0.1, model__kernel__length_scale=0.1;, score=-1.136 total time=   0.3s
# [CV 2/5] END model__alpha=0.1, model__kernel__length_scale=0.1;, score=-2.535 total time=   0.2s
# [CV 3/5] END model__alpha=0.1, model__kernel__length_scale=0.1;, score=-1.014 total time=   0.2s
# [CV 4/5] END model__alpha=0.1, model__kernel__length_scale=0.1;, score=-4.557 total time=   0.3s
# [CV 5/5] END model__alpha=0.1, model__kernel__length_scale=0.1;, score=-2.033 total time=   0.4s
# [CV 1/5] END model__alpha=0.1, model__kernel__length_scale=1;, score=0.808 total time=   0.2s
# [CV 2/5] END model__alpha=0.1, model__kernel__length_scale=1;, score=0.837 total time=   0.1s
# [CV 3/5] END model__alpha=0.1, model__kernel__length_scale=1;, score=0.742 total time=   0.0s
# [CV 4/5] END model__alpha=0.1, model__kernel__length_scale=1;, score=0.852 total time=   0.0s
# [CV 5/5] END model__alpha=0.1, model__kernel__length_scale=1;, score=0.867 total time=   0.0s
# [CV 1/5] END model__alpha=0.1, model__kernel__length_scale=10;, score=0.375 total time=   0.1s
# [CV 2/5] END model__alpha=0.1, model__kernel__length_scale=10;, score=0.490 total time=   0.2s
# [CV 3/5] END model__alpha=0.1, model__kernel__length_scale=10;, score=0.372 total time=   0.0s
# [CV 4/5] END model__alpha=0.1, model__kernel__length_scale=10;, score=0.465 total time=   0.0s
# [CV 5/5] END model__alpha=0.1, model__kernel__length_scale=10;, score=0.484 total time=   0.1s
# Training set R2 values: [0.91461255 0.92009601 0.94893232 0.87975237]. Uniform average: 0.9158483114601117
# Relative L2 error on test set: [ 0.41483786  0.45181628 10.01908512 99.39100563]
# Relative L2 error on training set: [0.08575268 0.1553718  0.20964341 0.29483926]

# %%
from sklearn.neural_network import MLPRegressor

pipe = Pipeline([('scaler', MaxAbsScaler()),
                  ('model', MLPRegressor(activation='tanh', hidden_layer_sizes=(50, 10), alpha=1e-2, learning_rate_init=0.001, max_iter=4000, verbose=True, tol=1e-12, batch_size=64, n_iter_no_change=50, validation_fraction=0.1))])
# params = {'model__hidden_layer_sizes': [(20, 10), (20, 10, 5), (50, 30, 10), (10, 5)],
#           'model__alpha': [1e-4, 1e-3, 1e-2, 1e-1],
#           'model__learning_rate_init': [1e-3, 1e-2, 1e-1]
#           }
# model = GridSearchCV(pipe, params, cv=10, verbose=3)
model = pipe
model.fit(xtrain, ytrain)
r2 = model.score(xtrain, ytrain)
yt_ridge = model.predict(xtest)
ytrain_ridge = model.predict(xtrain)
r2 = 1 - np.sum((ytrain_ridge - ytrain)**2, axis=0) / np.sum((ytrain_ridge - np.mean(ytrain_ridge, axis=0))**2, axis=0)
rel_error = np.sqrt(np.mean((ytest - yt_ridge)**2, axis=0)) / np.sqrt(np.mean(ytest**2, axis=0))     # (Nq,)
print(f'Training set R2 values: {r2}. Uniform average: {np.mean(r2)}')
print(f'Relative L2 error on test set: {rel_error}')
rel_error = np.sqrt(np.mean((ytrain - ytrain_ridge)**2, axis=0)) / np.sqrt(np.mean(ytrain**2, axis=0))     # (Nq,)
print(f'Relative L2 error on training set: {rel_error}')

fig, axs = plt.subplots(1, len(sys_qoi))
for i in range(len(sys_qoi)):
    ax = axs[i] if len(sys_qoi) > 1 else axs
    ax.scatter(ytrain[:, i], ytrain_ridge[:, i], c='r', s=1.5)
    ax.plot(ytrain[:, i], ytrain[:, i], '-k')
    ax.set_title(labels[i])
    ax_default(ax, 'Actual', 'Predicted', legend=False)
fig.set_size_inches(3*len(sys_qoi), 3)
fig.tight_layout()
plt.show()
# Out:
# Iteration 3935, loss = 1.18983949
# Iteration 3936, loss = 1.20147929
# Iteration 3937, loss = 1.20920239
# Iteration 3938, loss = 1.25273548
# Iteration 3939, loss = 1.26521406
# Iteration 3940, loss = 1.19518447
# Iteration 3941, loss = 1.18297021
# Iteration 3942, loss = 1.17189100
# Iteration 3943, loss = 1.19036208
# Iteration 3944, loss = 1.19336792
# Iteration 3945, loss = 1.16823184
# Iteration 3946, loss = 1.18976247
# Iteration 3947, loss = 1.19225446
# Iteration 3948, loss = 1.17926399
# Iteration 3949, loss = 1.16918586
# Iteration 3950, loss = 1.16979382
# Iteration 3951, loss = 1.17835165
# Iteration 3952, loss = 1.17567961
# Iteration 3953, loss = 1.17799772
# Iteration 3954, loss = 1.17108315
# Iteration 3955, loss = 1.19990780
# Iteration 3956, loss = 1.18465941
# Iteration 3957, loss = 1.16717686
# Iteration 3958, loss = 1.16348973
# Iteration 3959, loss = 1.16819400
# Iteration 3960, loss = 1.20305534
# Iteration 3961, loss = 1.18338828
# Iteration 3962, loss = 1.22071708
# Iteration 3963, loss = 1.17006781
# Iteration 3964, loss = 1.24569251
# Iteration 3965, loss = 1.18374487
# Iteration 3966, loss = 1.17558822
# Iteration 3967, loss = 1.18510467
# Iteration 3968, loss = 1.16327040
# Iteration 3969, loss = 1.17128542
# Iteration 3970, loss = 1.18223626
# Iteration 3971, loss = 1.20559660
# Iteration 3972, loss = 1.16704486
# Iteration 3973, loss = 1.14076245
# Iteration 3974, loss = 1.17038018
# Iteration 3975, loss = 1.15183050
# Iteration 3976, loss = 1.14936539
# Iteration 3977, loss = 1.17398547
# Iteration 3978, loss = 1.24498930
# Iteration 3979, loss = 1.18178487
# Iteration 3980, loss = 1.19138284
# Iteration 3981, loss = 1.19788935
# Iteration 3982, loss = 1.18500843
# Iteration 3983, loss = 1.21065683
# Iteration 3984, loss = 1.22315984
# Iteration 3985, loss = 1.15799290
# Iteration 3986, loss = 1.15935078
# Iteration 3987, loss = 1.17204452
# Iteration 3988, loss = 1.15692152
# Iteration 3989, loss = 1.16791406
# Iteration 3990, loss = 1.17719375
# Iteration 3991, loss = 1.14612604
# Iteration 3992, loss = 1.15019179
# Iteration 3993, loss = 1.14862924
# Iteration 3994, loss = 1.13926141
# Iteration 3995, loss = 1.15900465
# Iteration 3996, loss = 1.14585107
# Iteration 3997, loss = 1.17503152
# Iteration 3998, loss = 1.16624460
# Iteration 3999, loss = 1.17443727
# Iteration 4000, loss = 1.16061642
# Training set R2 values: [0.68635639 0.98828066 0.94915396 0.92306855]. Uniform average: 0.8867148916240902
# Relative L2 error on test set: [  0.37203684   0.30329913  11.7137838  118.9781914 ]
# Relative L2 error on training set: [0.14878726 0.06280972 0.21332067 0.2488765 ]
# /mnt/c/Users/gemte/Desktop/University/SummerResearch24/HallThrusterPEM/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
l = model['model'].loss_curve_
fig, ax = plt.subplots()
ax.plot(l, '-k')
ax.set_yscale('log')
ax_default(ax, 'Iteration', 'Loss', legend=False)
plt.show()

# %%
# Scatter plots of input/output spaces
from uqtils import ndscatter

# labels = [var.to_tex() for var in surr['Thruster'].x_vars]
labels = [var.to_tex() for i, var in enumerate(surr.coupling_vars) if i in sys_qoi]
fig, ax = ndscatter(ytest, labels=labels, subplot_size=2)
plt.show()
# Out:
# /mnt/c/Users/gemte/Desktop/University/SummerResearch24/HallThrusterPEM/.venv/lib/python3.11/site-packages/uqtils/plots.py:267: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   sc = ax.scatter(samples[:, j], samples[:, i], s=1.5, c=z, cmap=cmap, norm=cb_norm)
# /mnt/c/Users/gemte/Desktop/University/SummerResearch24/HallThrusterPEM/.venv/lib/python3.11/site-packages/uqtils/plots.py:267: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   sc = ax.scatter(samples[:, j], samples[:, i], s=1.5, c=z, cmap=cmap, norm=cb_norm)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 6
#       4 # labels = [var.to_tex() for var in surr['Thruster'].x_vars]
#       5 labels = [var.to_tex() for i, var in enumerate(surr.coupling_vars) if i in sys_qoi]
# ----> 6 fig, ax = ndscatter(ytest, labels=labels, subplot_size=2)
#       7 plt.show()
#
# ValueError: too many values to unpack (expected 2)

# %%
# Find what is causing negative thrust and NaN cases
import os
save_dir = 'build_2023-07-18T01.48.39'
root_dir = Path('../surrogates') / save_dir / 'components' / 'Thruster'
x = np.zeros((0, 14))
y = np.zeros((0, 26))
for f in os.listdir(root_dir):
    if f.endswith('.pkl'):
        with open(root_dir / f, 'rb') as fd:
            data = pickle.load(fd)
            x = np.concatenate((x, data['x']), axis=0)
            y = np.concatenate((y, data['y']), axis=0)
x.shape, y.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 7
#       5 x = np.zeros((0, 14))
#       6 y = np.zeros((0, 26))
# ----> 7 for f in os.listdir(root_dir):
#       8     if f.endswith('.pkl'):
#       9         with open(root_dir / f, 'rb') as fd:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../surrogates/build_2023-07-18T01.48.39/components/Thruster'

# %%
nan_idx = np.where(np.any(np.isnan(y), axis=-1))[0]
neg_idx = np.where(y[:, 1] < 0)[0]
nan_idx.shape, neg_idx.shape
# Out:
# ((0,), (0,))

# %%
fig, axs = plt.subplots(7, 2)
curr_idx = 0
thruster_idx = [0, 1, 2, 3, 7, 8, 9, 10, 11, 12, 13, 14, 15]
labels = [str(var) for i, var in enumerate(surr.exo_vars) if i in thruster_idx] + ['V_cc']
for i in range(7):
    for j in range(2):
        ax = axs[i, j]
        ax.hist(x[nan_idx, curr_idx], color='red', linewidth=1.2, density=True, bins=15)
        ax_default(ax, labels[curr_idx], '', legend=False)
        curr_idx += 1
fig.set_size_inches(4, 14)
fig.tight_layout()
plt.show()
# Out:
# /mnt/c/Users/gemte/Desktop/University/SummerResearch24/HallThrusterPEM/.venv/lib/python3.11/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
